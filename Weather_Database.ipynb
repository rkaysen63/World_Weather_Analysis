# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# Declare each array as a variable to access later.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack lat_lngs zip object into a list, i.e. add the latitudes and longitudes to a list. 
# You can only unzip a zipped tuple once before it is removed from the computer's memory. 
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
# citipy module finds nearest city to lat and long pr w/pop >= 500. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Determine total number of cities.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
# units=Imperial
# weather_api_key variable calls my api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list. 
# numerate() method is alternative way to iterate through the list 
# of cities and retrieve both the index and the city from the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # modulus i % 50 gives yields remainder of i/50.
    # if statement is true then the set_count and the record_count are incremented by 1
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    # Remove blank spaces in the city name and concatenating the city name with city.replace(" ","+")
    # in order to find the corresponding weather data for city instead of for first part of city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    # Print the record count and set count and city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
               
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | pangnirtung
# Processing Record 2 of Set 1 | avera
# Processing Record 3 of Set 1 | northam
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | gejiu
# Processing Record 7 of Set 1 | sinnamary
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | ancud
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | mizdah
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | bari
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | udachnyy
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | rae bareli
# Processing Record 29 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 1 | swellendam
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | poum
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | hamilton
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | fonte boa
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | ocampo
# Processing Record 44 of Set 1 | vanavara
# Processing Record 45 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 46 of Set 1 | kirakira
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | hirara
# Processing Record 1 of Set 2 | chabahar
# Processing Record 2 of Set 2 | keuruu
# Processing Record 3 of Set 2 | kamina
# Processing Record 4 of Set 2 | acapulco
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | karasburg
# Processing Record 7 of Set 2 | hambantota
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | odesskoye
# Processing Record 10 of Set 2 | rawicz
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | ketchikan
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | iracoubo
# Processing Record 19 of Set 2 | noumea
# Processing Record 20 of Set 2 | lebedinyy
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | chateauroux
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | bilibino
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | chongwe
# Processing Record 31 of Set 2 | peleduy
# Processing Record 32 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | sao jose da coroa grande
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | kalemie
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | camacha
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | santa vitoria
# Processing Record 50 of Set 2 | coahuayana
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | nokaneng
# Processing Record 3 of Set 3 | aloleng
# Processing Record 4 of Set 3 | sao raimundo nonato
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | maragogi
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | wawa
# Processing Record 10 of Set 3 | pesaro
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | karratha
# Processing Record 16 of Set 3 | meulaboh
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | jeremie
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | zabid
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | kampot
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 3 | buraydah
# Processing Record 28 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 3 | petropavl
# Processing Record 30 of Set 3 | sorland
# Processing Record 31 of Set 3 | diapaga
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | capoterra
# Processing Record 37 of Set 3 | kaliua
# Processing Record 38 of Set 3 | wonosobo
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | tairua
# Processing Record 41 of Set 3 | leshukonskoye
# Processing Record 42 of Set 3 | manga
# Processing Record 43 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 3 | dingle
# Processing Record 45 of Set 3 | qaqortoq
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | tomatlan
# Processing Record 48 of Set 3 | griffith
# Processing Record 49 of Set 3 | konstantinovka
# Processing Record 50 of Set 3 | zhezkazgan
# Processing Record 1 of Set 4 | scarborough
# Processing Record 2 of Set 4 | sabang
# Processing Record 3 of Set 4 | tahe
# Processing Record 4 of Set 4 | mitu
# Processing Record 5 of Set 4 | muros
# Processing Record 6 of Set 4 | carutapera
# Processing Record 7 of Set 4 | cururupu
# Processing Record 8 of Set 4 | hervey bay
# Processing Record 9 of Set 4 | sala
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | pombas
# Processing Record 13 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 4 | molodiya
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | mayo
# Processing Record 17 of Set 4 | vostok
# Processing Record 18 of Set 4 | pervomayskiy
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | gornopravdinsk
# Processing Record 21 of Set 4 | chifeng
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | vaini
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | tubuala
# Processing Record 26 of Set 4 | zhigansk
# Processing Record 27 of Set 4 | khandyga
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | paraiso
# Processing Record 30 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 4 | patacamaya
# Processing Record 32 of Set 4 | sola
# Processing Record 33 of Set 4 | exu
# Processing Record 34 of Set 4 | broken hill
# Processing Record 35 of Set 4 | batemans bay
# Processing Record 36 of Set 4 | catuday
# Processing Record 37 of Set 4 | rawlins
# Processing Record 38 of Set 4 | korla
# Processing Record 39 of Set 4 | bivolari
# Processing Record 40 of Set 4 | nioro
# Processing Record 41 of Set 4 | udaipura
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | jumla
# Processing Record 44 of Set 4 | bud
# Processing Record 45 of Set 4 | ejido
# Processing Record 46 of Set 4 | havoysund
# Processing Record 47 of Set 4 | sangar
# Processing Record 48 of Set 4 | yerbogachen
# Processing Record 49 of Set 4 | burica
# City not found. Skipping...
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | lar gerd
# City not found. Skipping...
# Processing Record 6 of Set 5 | tonantins
# Processing Record 7 of Set 5 | coihueco
# Processing Record 8 of Set 5 | banjar
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | los llanos de aridane
# Processing Record 11 of Set 5 | yuty
# Processing Record 12 of Set 5 | mar del plata
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | khash
# Processing Record 15 of Set 5 | rancho palos verdes
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | beringovskiy
# Processing Record 18 of Set 5 | moorhead
# Processing Record 19 of Set 5 | puerto madryn
# Processing Record 20 of Set 5 | san remo
# Processing Record 21 of Set 5 | strezhevoy
# Processing Record 22 of Set 5 | praya
# Processing Record 23 of Set 5 | kuala terengganu
# Processing Record 24 of Set 5 | rawson
# Processing Record 25 of Set 5 | ulaanbaatar
# Processing Record 26 of Set 5 | bougouni
# Processing Record 27 of Set 5 | rosamorada
# Processing Record 28 of Set 5 | anjozorobe
# Processing Record 29 of Set 5 | vila franca do campo
# Processing Record 30 of Set 5 | husavik
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | severo-kurilsk
# Processing Record 33 of Set 5 | uchiza
# Processing Record 34 of Set 5 | umm lajj
# Processing Record 35 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 5 | mollendo
# Processing Record 37 of Set 5 | ponta delgada
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | karsun
# Processing Record 40 of Set 5 | christchurch
# Processing Record 41 of Set 5 | ous
# Processing Record 42 of Set 5 | nyrob
# Processing Record 43 of Set 5 | yanam
# Processing Record 44 of Set 5 | gagnoa
# Processing Record 45 of Set 5 | pilot butte
# Processing Record 46 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 5 | lujan
# Processing Record 48 of Set 5 | inuvik
# Processing Record 49 of Set 5 | balakhninskiy
# Processing Record 50 of Set 5 | adre
# Processing Record 1 of Set 6 | paracuru
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | ciudad real
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | tautira
# Processing Record 6 of Set 6 | ofaqim
# Processing Record 7 of Set 6 | leningradskiy
# Processing Record 8 of Set 6 | elko
# Processing Record 9 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 10 of Set 6 | conceicao do araguaia
# Processing Record 11 of Set 6 | gornyatskiy
# Processing Record 12 of Set 6 | marsa matruh
# Processing Record 13 of Set 6 | kodiak
# Processing Record 14 of Set 6 | almonte
# Processing Record 15 of Set 6 | amapa
# Processing Record 16 of Set 6 | umm kaddadah
# Processing Record 17 of Set 6 | puerto colombia
# Processing Record 18 of Set 6 | bonthe
# Processing Record 19 of Set 6 | mucuri
# Processing Record 20 of Set 6 | muroto
# Processing Record 21 of Set 6 | uyuni
# Processing Record 22 of Set 6 | nusaybin
# Processing Record 23 of Set 6 | wagar
# Processing Record 24 of Set 6 | broome
# Processing Record 25 of Set 6 | san cristobal
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | graaff-reinet
# Processing Record 28 of Set 6 | rokytne
# Processing Record 29 of Set 6 | srednekolymsk
# Processing Record 30 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | bethel
# Processing Record 34 of Set 6 | dunedin
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | dolores
# Processing Record 37 of Set 6 | mount isa
# Processing Record 38 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 6 | port augusta
# Processing Record 40 of Set 6 | port arthur
# Processing Record 41 of Set 6 | krasnoselkup
# Processing Record 42 of Set 6 | grand-santi
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | conceicao da barra
# Processing Record 45 of Set 6 | vysokogornyy
# Processing Record 46 of Set 6 | kysyl-syr
# Processing Record 47 of Set 6 | kapuskasing
# Processing Record 48 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 6 | moron
# Processing Record 50 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 7 | port hardy
# Processing Record 2 of Set 7 | molochnoye
# Processing Record 3 of Set 7 | norwich
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | makakilo city
# Processing Record 6 of Set 7 | turukhansk
# Processing Record 7 of Set 7 | quatre cocos
# Processing Record 8 of Set 7 | calvia
# Processing Record 9 of Set 7 | manokwari
# Processing Record 10 of Set 7 | sesheke
# Processing Record 11 of Set 7 | yulara
# Processing Record 12 of Set 7 | zemetchino
# Processing Record 13 of Set 7 | rock sound
# Processing Record 14 of Set 7 | bontang
# Processing Record 15 of Set 7 | awbari
# Processing Record 16 of Set 7 | russell
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | cap-aux-meules
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | inverell
# Processing Record 21 of Set 7 | zamora
# Processing Record 22 of Set 7 | barra dos coqueiros
# Processing Record 23 of Set 7 | sidi ali
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | burnie
# Processing Record 26 of Set 7 | douala
# Processing Record 27 of Set 7 | akdepe
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | porto walter
# Processing Record 30 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 7 | roald
# Processing Record 32 of Set 7 | port macquarie
# Processing Record 33 of Set 7 | loandjili
# Processing Record 34 of Set 7 | saint-jean-port-joli
# Processing Record 35 of Set 7 | pingliang
# Processing Record 36 of Set 7 | pacific grove
# Processing Record 37 of Set 7 | tromso
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | auki
# Processing Record 40 of Set 7 | tawang
# Processing Record 41 of Set 7 | souillac
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | kangaatsiaq
# Processing Record 44 of Set 7 | kudahuvadhoo
# Processing Record 45 of Set 7 | dutlwe
# Processing Record 46 of Set 7 | hobyo
# Processing Record 47 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 7 | pajapan
# Processing Record 49 of Set 7 | westport
# Processing Record 50 of Set 7 | ixtlahuacan del rio
# Processing Record 1 of Set 8 | fairbanks
# Processing Record 2 of Set 8 | kargasok
# Processing Record 3 of Set 8 | puquio
# Processing Record 4 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 8 | njombe
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | mari-turek
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | uribia
# Processing Record 11 of Set 8 | axim
# Processing Record 12 of Set 8 | maraa
# Processing Record 13 of Set 8 | kodinsk
# Processing Record 14 of Set 8 | manavalakurichi
# Processing Record 15 of Set 8 | valparaiso
# Processing Record 16 of Set 8 | hasaki
# Processing Record 17 of Set 8 | half moon bay
# Processing Record 18 of Set 8 | poso
# Processing Record 19 of Set 8 | yasnyy
# Processing Record 20 of Set 8 | ugoofaaru
# Processing Record 21 of Set 8 | kribi
# Processing Record 22 of Set 8 | colares
# Processing Record 23 of Set 8 | ponnani
# Processing Record 24 of Set 8 | illapel
# Processing Record 25 of Set 8 | tripoli
# Processing Record 26 of Set 8 | roebourne
# Processing Record 27 of Set 8 | cozumel
# Processing Record 28 of Set 8 | katima mulilo
# Processing Record 29 of Set 8 | aracaju
# Processing Record 30 of Set 8 | belle fourche
# Processing Record 31 of Set 8 | saint-georges
# Processing Record 32 of Set 8 | onega
# Processing Record 33 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 8 | roma
# Processing Record 35 of Set 8 | xiaoweizhai
# Processing Record 36 of Set 8 | yining
# Processing Record 37 of Set 8 | beisfjord
# Processing Record 38 of Set 8 | avaton
# Processing Record 39 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | guanica
# Processing Record 43 of Set 8 | asheboro
# Processing Record 44 of Set 8 | camana
# Processing Record 45 of Set 8 | lichinga
# Processing Record 46 of Set 8 | lagoa
# Processing Record 47 of Set 8 | verkhnyaya inta
# Processing Record 48 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 8 | asau
# Processing Record 50 of Set 8 | wamba
# Processing Record 1 of Set 9 | wisconsin rapids
# Processing Record 2 of Set 9 | calais
# Processing Record 3 of Set 9 | esna
# Processing Record 4 of Set 9 | troitsko-pechorsk
# Processing Record 5 of Set 9 | khasan
# Processing Record 6 of Set 9 | keti bandar
# Processing Record 7 of Set 9 | bonavista
# Processing Record 8 of Set 9 | alice springs
# Processing Record 9 of Set 9 | bima
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | crotone
# Processing Record 12 of Set 9 | hattiesburg
# Processing Record 13 of Set 9 | orlik
# Processing Record 14 of Set 9 | vung tau
# Processing Record 15 of Set 9 | houma
# Processing Record 16 of Set 9 | lagos
# Processing Record 17 of Set 9 | kloulklubed
# Processing Record 18 of Set 9 | port blair
# Processing Record 19 of Set 9 | kununurra
# Processing Record 20 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 9 | kiama
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | aksu
# Processing Record 24 of Set 9 | martapura
# Processing Record 25 of Set 9 | emba
# Processing Record 26 of Set 9 | erenhot
# Processing Record 27 of Set 9 | inirida
# Processing Record 28 of Set 9 | sant feliu de guixols
# Processing Record 29 of Set 9 | palmas
# Processing Record 30 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 9 | dulyapino
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | bilma
# Processing Record 34 of Set 9 | klamath falls
# Processing Record 35 of Set 9 | hofn
# Processing Record 36 of Set 9 | chapais
# Processing Record 37 of Set 9 | port lincoln
# Processing Record 38 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 9 | mega
# Processing Record 40 of Set 9 | raahe
# Processing Record 41 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 9 | ola
# Processing Record 43 of Set 9 | kitui
# Processing Record 44 of Set 9 | perez
# Processing Record 45 of Set 9 | cheremukhovo
# Processing Record 46 of Set 9 | clyde river
# Processing Record 47 of Set 9 | camopi
# Processing Record 48 of Set 9 | narsaq
# Processing Record 49 of Set 9 | bruck an der leitha
# Processing Record 50 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 1 of Set 10 | ilebo
# Processing Record 2 of Set 10 | zhigalovo
# Processing Record 3 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 10 | hami
# Processing Record 5 of Set 10 | kahului
# Processing Record 6 of Set 10 | aykhal
# Processing Record 7 of Set 10 | ilabaya
# Processing Record 8 of Set 10 | puri
# Processing Record 9 of Set 10 | riyadh
# Processing Record 10 of Set 10 | maniitsoq
# Processing Record 11 of Set 10 | madang
# Processing Record 12 of Set 10 | sao miguel do araguaia
# Processing Record 13 of Set 10 | encarnacion
# Processing Record 14 of Set 10 | bowen
# Processing Record 15 of Set 10 | itoman
# Processing Record 16 of Set 10 | suluq
# Processing Record 17 of Set 10 | huangzhou
# Processing Record 18 of Set 10 | rong kwang
# Processing Record 19 of Set 10 | kinshasa
# Processing Record 20 of Set 10 | honolulu
# Processing Record 21 of Set 10 | tucupita
# Processing Record 22 of Set 10 | gamba
# Processing Record 23 of Set 10 | shetpe
# Processing Record 24 of Set 10 | vila
# Processing Record 25 of Set 10 | kalmunai
# Processing Record 26 of Set 10 | sisimiut
# Processing Record 27 of Set 10 | kjollefjord
# Processing Record 28 of Set 10 | awallan
# Processing Record 29 of Set 10 | paratinga
# Processing Record 30 of Set 10 | pozuelo de alarcon
# Processing Record 31 of Set 10 | honningsvag
# Processing Record 32 of Set 10 | isparta
# Processing Record 33 of Set 10 | vanimo
# Processing Record 34 of Set 10 | vestmannaeyjar
# Processing Record 35 of Set 10 | smederevo
# Processing Record 36 of Set 10 | tshikapa
# Processing Record 37 of Set 10 | anuradhapura
# Processing Record 38 of Set 10 | gambela
# Processing Record 39 of Set 10 | kalas
# Processing Record 40 of Set 10 | gat
# Processing Record 41 of Set 10 | micheweni
# Processing Record 42 of Set 10 | coihaique
# Processing Record 43 of Set 10 | zhangjiakou
# Processing Record 44 of Set 10 | tsogni
# Processing Record 45 of Set 10 | san joaquin
# Processing Record 46 of Set 10 | nizhnyaya poyma
# Processing Record 47 of Set 10 | salinopolis
# Processing Record 48 of Set 10 | carlyle
# Processing Record 49 of Set 10 | mezen
# Processing Record 50 of Set 10 | fortuna
# Processing Record 1 of Set 11 | raymondville
# Processing Record 2 of Set 11 | mecca
# Processing Record 3 of Set 11 | tongzi
# Processing Record 4 of Set 11 | tura
# Processing Record 5 of Set 11 | ivanava
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 11 | the valley
# Processing Record 9 of Set 11 | port elizabeth
# Processing Record 10 of Set 11 | praia
# Processing Record 11 of Set 11 | garcia hernandez
# Processing Record 12 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 11 | chor
# Processing Record 14 of Set 11 | tashla
# Processing Record 15 of Set 11 | kuryk
# Processing Record 16 of Set 11 | ye
# City not found. Skipping...
# Processing Record 17 of Set 11 | coos bay
# Processing Record 18 of Set 11 | labuhan
# Processing Record 19 of Set 11 | tezu
# Processing Record 20 of Set 11 | bitung
# Processing Record 21 of Set 11 | mae hong son
# Processing Record 22 of Set 11 | iguape
# Processing Record 23 of Set 11 | gasa
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | freeport
# Processing Record 27 of Set 11 | tecuala
# Processing Record 28 of Set 11 | kulhudhuffushi
# Processing Record 29 of Set 11 | armizonskoye
# Processing Record 30 of Set 11 | manzil salim
# Processing Record 31 of Set 11 | eldorado
# Processing Record 32 of Set 11 | wajima
# Processing Record 33 of Set 11 | noshiro
# Processing Record 34 of Set 11 | santa cruz cabralia
# Processing Record 35 of Set 11 | tanabe
# Processing Record 36 of Set 11 | porto belo
# Processing Record 37 of Set 11 | ulladulla
# Processing Record 38 of Set 11 | conde
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | dmitriyevskaya
# Processing Record 41 of Set 11 | veinticinco de mayo
# Processing Record 42 of Set 11 | kabalo
# Processing Record 43 of Set 11 | sioux lookout
# Processing Record 44 of Set 11 | shenjiamen
# Processing Record 45 of Set 11 | luanda
# Processing Record 46 of Set 11 | aquiraz
# Processing Record 47 of Set 11 | saint-joseph
# Processing Record 48 of Set 11 | orodara
# Processing Record 49 of Set 11 | hagenow
# Processing Record 50 of Set 11 | totness
# Processing Record 1 of Set 12 | dauphin
# Processing Record 2 of Set 12 | sur
# Processing Record 3 of Set 12 | asilah
# Processing Record 4 of Set 12 | yacuiba
# Processing Record 5 of Set 12 | demmin
# Processing Record 6 of Set 12 | puerto leguizamo
# Processing Record 7 of Set 12 | havelock
# Processing Record 8 of Set 12 | chibombo
# Processing Record 9 of Set 12 | save
# Processing Record 10 of Set 12 | pevek
# Processing Record 11 of Set 12 | mazyr
# Processing Record 12 of Set 12 | shenzhen
# Processing Record 13 of Set 12 | tyup
# Processing Record 14 of Set 12 | barneveld
# Processing Record 15 of Set 12 | naze
# Processing Record 16 of Set 12 | tilichiki
# Processing Record 17 of Set 12 | bibiani
# Processing Record 18 of Set 12 | mehran
# Processing Record 19 of Set 12 | yarmouth
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | palmital
# Processing Record 22 of Set 12 | tullamore
# Processing Record 23 of Set 12 | barentu
# Processing Record 24 of Set 12 | luba
# Processing Record 25 of Set 12 | visby
# Processing Record 26 of Set 12 | soe
# Processing Record 27 of Set 12 | brainerd
# Processing Record 28 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 12 | vadinsk
# Processing Record 30 of Set 12 | sao joao da barra
# Processing Record 31 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 12 | aksha
# Processing Record 33 of Set 12 | mulege
# Processing Record 34 of Set 12 | hemsedal
# Processing Record 35 of Set 12 | yasnogorsk
# Processing Record 36 of Set 12 | toamasina
# Processing Record 37 of Set 12 | wattegama
# Processing Record 38 of Set 12 | disna
# Processing Record 39 of Set 12 | mehamn
# Processing Record 40 of Set 12 | troitskoye
# Processing Record 41 of Set 12 | sambava
# Processing Record 42 of Set 12 | cumana
# Processing Record 43 of Set 12 | anshun
# Processing Record 44 of Set 12 | naifaru
# Processing Record 45 of Set 12 | waddan
# Processing Record 46 of Set 12 | barabinsk
# Processing Record 47 of Set 12 | buala
# Processing Record 48 of Set 12 | yar-sale
# Processing Record 49 of Set 12 | kaeo
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | providencia
# Processing Record 2 of Set 13 | xicotencatl
# Processing Record 3 of Set 13 | bambanglipuro
# Processing Record 4 of Set 13 | watertown
# Processing Record 5 of Set 13 | kawalu
# Processing Record 6 of Set 13 | namie
# Processing Record 7 of Set 13 | dzhebariki-khaya
# Processing Record 8 of Set 13 | las vegas
# Processing Record 9 of Set 13 | dubti
# Processing Record 10 of Set 13 | presque isle
# Processing Record 11 of Set 13 | xining
# Processing Record 12 of Set 13 | la ronge
# Processing Record 13 of Set 13 | elliot lake
# Processing Record 14 of Set 13 | upata
# Processing Record 15 of Set 13 | taree
# Processing Record 16 of Set 13 | walvis bay
# Processing Record 17 of Set 13 | pemangkat
# Processing Record 18 of Set 13 | mayor pablo lagerenza
# Processing Record 19 of Set 13 | ambilobe
# Processing Record 20 of Set 13 | luderitz
# Processing Record 21 of Set 13 | jizan
# Processing Record 22 of Set 13 | salalah
# Processing Record 23 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | santa lucia
# Processing Record 25 of Set 13 | umea
# Processing Record 26 of Set 13 | bandrele
# Processing Record 27 of Set 13 | poya
# Processing Record 28 of Set 13 | redmond
# Processing Record 29 of Set 13 | a
# City not found. Skipping...
# Processing Record 30 of Set 13 | aleksandrovka
# Processing Record 31 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 13 | cap malheureux
# Processing Record 33 of Set 13 | kemijarvi
# Processing Record 34 of Set 13 | marsh harbour
# Processing Record 35 of Set 13 | shitanjing
# Processing Record 36 of Set 13 | shingu
# Processing Record 37 of Set 13 | pontal do parana
# Processing Record 38 of Set 13 | viedma
# Processing Record 39 of Set 13 | iesolo
# Processing Record 40 of Set 13 | novopokrovka
# Processing Record 41 of Set 13 | schwedt
# Processing Record 42 of Set 13 | bolitoc
# Processing Record 43 of Set 13 | farafangana
# Processing Record 44 of Set 13 | tecolutla
# Processing Record 45 of Set 13 | anyksciai
# Processing Record 46 of Set 13 | port victoria
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | ereymentau
# Processing Record 49 of Set 13 | quetta
# Processing Record 50 of Set 13 | faranah
# Processing Record 1 of Set 14 | grindavik
# Processing Record 2 of Set 14 | elat
# Processing Record 3 of Set 14 | shipunovo
# Processing Record 4 of Set 14 | xichang
# Processing Record 5 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 14 | marzuq
# Processing Record 7 of Set 14 | lakatoro
# Processing Record 8 of Set 14 | filingue
# Processing Record 9 of Set 14 | okato
# Processing Record 10 of Set 14 | neya
# Processing Record 11 of Set 14 | aconibe
# Processing Record 12 of Set 14 | cockburn town
# Processing Record 13 of Set 14 | port-cartier
# Processing Record 14 of Set 14 | waingapu
# Processing Record 15 of Set 14 | marawi
# Processing Record 16 of Set 14 | tortoli
# Processing Record 17 of Set 14 | dawson creek
# Processing Record 18 of Set 14 | shimoda
# Processing Record 19 of Set 14 | nemuro
# Processing Record 20 of Set 14 | lompoc
# Processing Record 21 of Set 14 | ballina
# Processing Record 22 of Set 14 | kazanskaya
# Processing Record 23 of Set 14 | chilca
# Processing Record 24 of Set 14 | isabela
# Processing Record 25 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | kerman
# Processing Record 27 of Set 14 | ucluelet
# Processing Record 28 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 14 | teknaf
# Processing Record 30 of Set 14 | san policarpo
# Processing Record 31 of Set 14 | san vicente
# Processing Record 32 of Set 14 | mahibadhoo
# Processing Record 33 of Set 14 | vulcan
# Processing Record 34 of Set 14 | khajuraho
# Processing Record 35 of Set 14 | baicheng
# Processing Record 36 of Set 14 | belaya gora
# Processing Record 37 of Set 14 | wurzen
# Processing Record 38 of Set 14 | rorvik
# Processing Record 39 of Set 14 | inhambane
# Processing Record 40 of Set 14 | yumen
# Processing Record 41 of Set 14 | luxor
# Processing Record 42 of Set 14 | basoko
# Processing Record 43 of Set 14 | antalaha
# Processing Record 44 of Set 14 | karpathos
# Processing Record 45 of Set 14 | whitehorse
# Processing Record 46 of Set 14 | ardakan
# Processing Record 47 of Set 14 | qatana
# Processing Record 48 of Set 14 | benoy
# Processing Record 49 of Set 14 | gumusyaka
# City not found. Skipping...
# Processing Record 50 of Set 14 | bucerias
# Processing Record 1 of Set 15 | esmeraldas
# Processing Record 2 of Set 15 | simga
# Processing Record 3 of Set 15 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 4 of Set 15 | bo phloi
# Processing Record 5 of Set 15 | kashi
# Processing Record 6 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 15 | hangu
# Processing Record 8 of Set 15 | aljezur
# Processing Record 9 of Set 15 | yenagoa
# Processing Record 10 of Set 15 | bereda
# Processing Record 11 of Set 15 | tanout
# Processing Record 12 of Set 15 | campoverde
# Processing Record 13 of Set 15 | blagoveshchensk
# Processing Record 14 of Set 15 | komsomolskiy
# Processing Record 15 of Set 15 | chom bung
# City not found. Skipping...
# Processing Record 16 of Set 15 | luganville
# Processing Record 17 of Set 15 | hengshui
# Processing Record 18 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 15 | santa cruz
# Processing Record 20 of Set 15 | omsukchan
# Processing Record 21 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 15 | agadez
# Processing Record 23 of Set 15 | tselinnoye
# Processing Record 24 of Set 15 | hualmay
# Processing Record 25 of Set 15 | novyy urengoy
# Processing Record 26 of Set 15 | polyarnyy
# Processing Record 27 of Set 15 | ambalavao
# Processing Record 28 of Set 15 | lobva
# Processing Record 29 of Set 15 | latung
# Processing Record 30 of Set 15 | iquique
# Processing Record 31 of Set 15 | phan thiet
# Processing Record 32 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 33 of Set 15 | brugg
# Processing Record 34 of Set 15 | north bend
# Processing Record 35 of Set 15 | santiago
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pangnirtung      CA  66.1451  -65.7125     17.60        79          90
# 1        Avera      US  33.1940  -82.5271     73.40        78           1
# 2      Northam      GB  51.0333   -4.2167     46.00        71          38
# 3        Bluff      NZ -46.6000  168.3333     55.99        93          98
# 4     Hermanus      ZA -34.4187   19.2345     64.99        83         100
# 5        Gejiu      CN  23.3060  103.1635     51.71        93          52
# 6    Sinnamary      GF   5.3833  -52.9500     82.45        72          53
# 7       Faanui      PF -16.4833 -151.7500     81.70        74          97
# 8        Ancud      CL -41.8697  -73.8203     57.99        82          75
# 9        Kapaa      US  22.0752 -159.3190     66.20        88          90
#
#    Wind Speed Current Description
# 0        2.42     overcast clouds
# 1        8.05           clear sky
# 2       11.99    scattered clouds
# 3        3.00     overcast clouds
# 4        3.56     overcast clouds
# 5        6.02       broken clouds
# 6        5.79       broken clouds
# 7        9.73     overcast clouds
# 8        9.22       broken clouds
# 9       11.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
