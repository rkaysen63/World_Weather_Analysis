# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# Declare each array as a variable to access later.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack lat_lngs zip object into a list, i.e. add the latitudes and longitudes to a list. 
# You can only unzip a zipped tuple once before it is removed from the computer's memory. 
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
# citipy module finds nearest city to lat and long pr w/pop >= 500. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Determine total number of cities.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
# units=Imperial
# weather_api_key variable calls my api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list. 
# numerate() method is alternative way to iterate through the list 
# of cities and retrieve both the index and the city from the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # modulus i % 50 gives yields remainder of i/50.
    # if statement is true then the set_count and the record_count are incremented by 1
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    # Remove blank spaces in the city name and concatenating the city name with city.replace(" ","+")
    # in order to find the corresponding weather data for city instead of for first part of city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    # Print the record count and set count and city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
               
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | albanel
# Processing Record 4 of Set 1 | buraydah
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | hofn
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | hoorn
# Processing Record 14 of Set 1 | vestmannaeyjar
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | beringovskiy
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | dawlatabad
# Processing Record 22 of Set 1 | haikou
# Processing Record 23 of Set 1 | anadyr
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | vuktyl
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 1 | deputatskiy
# Processing Record 31 of Set 1 | erenhot
# Processing Record 32 of Set 1 | takhtamygda
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | fort walton beach
# Processing Record 35 of Set 1 | samfya
# Processing Record 36 of Set 1 | mehamn
# Processing Record 37 of Set 1 | beira
# Processing Record 38 of Set 1 | kloulklubed
# Processing Record 39 of Set 1 | pisco
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | morondava
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | dipkarpaz
# City not found. Skipping...
# Processing Record 46 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | lagoa
# Processing Record 50 of Set 1 | aljezur
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | netanya
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | burgeo
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | huambo
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | bubaque
# Processing Record 12 of Set 2 | labelle
# Processing Record 13 of Set 2 | porto novo
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | te anau
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | jumla
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | west bay
# Processing Record 26 of Set 2 | rochegda
# Processing Record 27 of Set 2 | ordzhonikidze
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | geelong
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | okahandja
# Processing Record 32 of Set 2 | liverpool
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | swidnik
# Processing Record 35 of Set 2 | pangody
# Processing Record 36 of Set 2 | katubao
# Processing Record 37 of Set 2 | suba
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | dakar
# Processing Record 42 of Set 2 | rakai
# Processing Record 43 of Set 2 | rovaniemi
# Processing Record 44 of Set 2 | dejen
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | jaicos
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | jizan
# Processing Record 1 of Set 3 | sembe
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | russell
# Processing Record 4 of Set 3 | haines junction
# Processing Record 5 of Set 3 | linshu
# City not found. Skipping...
# Processing Record 6 of Set 3 | ambanja
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | birao
# Processing Record 9 of Set 3 | vilvoorde
# Processing Record 10 of Set 3 | louis trichardt
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | ballina
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | sisimiut
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | antigonish
# Processing Record 18 of Set 3 | pasighat
# Processing Record 19 of Set 3 | makakilo city
# Processing Record 20 of Set 3 | telsiai
# Processing Record 21 of Set 3 | komsomolskiy
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | port macquarie
# Processing Record 24 of Set 3 | kadiri
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | san luis potosi
# Processing Record 27 of Set 3 | dali
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | labytnangi
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | kysyl-syr
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | arman
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | manta
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | provideniya
# Processing Record 40 of Set 3 | neuquen
# Processing Record 41 of Set 3 | leirvik
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | yulara
# Processing Record 44 of Set 3 | presidencia roque saenz pena
# Processing Record 45 of Set 3 | ponta delgada
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | rucphen
# Processing Record 48 of Set 3 | waddan
# Processing Record 49 of Set 3 | sechura
# Processing Record 50 of Set 3 | batemans bay
# Processing Record 1 of Set 4 | rovinj
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | katobu
# Processing Record 4 of Set 4 | kamphaeng phet
# Processing Record 5 of Set 4 | siilinjarvi
# Processing Record 6 of Set 4 | grindavik
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | karabuk
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 4 | zhanaozen
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | coruripe
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | downers grove
# Processing Record 16 of Set 4 | tairua
# Processing Record 17 of Set 4 | bosaso
# Processing Record 18 of Set 4 | porto velho
# Processing Record 19 of Set 4 | quelimane
# Processing Record 20 of Set 4 | maryborough
# Processing Record 21 of Set 4 | sabha
# Processing Record 22 of Set 4 | nakhon nayok
# Processing Record 23 of Set 4 | port-cartier
# Processing Record 24 of Set 4 | nambucca heads
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | butaritari
# Processing Record 27 of Set 4 | chingirlau
# Processing Record 28 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | khatanga
# Processing Record 30 of Set 4 | sawtell
# Processing Record 31 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 4 | hushitai
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | camapua
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | sao gabriel da cachoeira
# Processing Record 41 of Set 4 | montepuez
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | beysehir
# Processing Record 44 of Set 4 | kungurtug
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | cartagena
# Processing Record 47 of Set 4 | el bagre
# Processing Record 48 of Set 4 | lashio
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | aksu
# Processing Record 1 of Set 5 | ossora
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | orimattila
# Processing Record 4 of Set 5 | zabid
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | porbandar
# Processing Record 7 of Set 5 | acari
# Processing Record 8 of Set 5 | hami
# Processing Record 9 of Set 5 | erzurum
# Processing Record 10 of Set 5 | lixourion
# Processing Record 11 of Set 5 | mandera
# Processing Record 12 of Set 5 | margate
# Processing Record 13 of Set 5 | poum
# Processing Record 14 of Set 5 | herend
# Processing Record 15 of Set 5 | vaitape
# Processing Record 16 of Set 5 | korla
# Processing Record 17 of Set 5 | anori
# Processing Record 18 of Set 5 | lunenburg
# Processing Record 19 of Set 5 | paamiut
# Processing Record 20 of Set 5 | victoria
# Processing Record 21 of Set 5 | mackay
# Processing Record 22 of Set 5 | kaitangata
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | tasgaon
# Processing Record 27 of Set 5 | liancheng
# Processing Record 28 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 5 | manokwari
# Processing Record 31 of Set 5 | outjo
# Processing Record 32 of Set 5 | zeliezovce
# Processing Record 33 of Set 5 | udomlya
# Processing Record 34 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 5 | urumqi
# Processing Record 38 of Set 5 | verkhnevilyuysk
# Processing Record 39 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 5 | trat
# Processing Record 41 of Set 5 | petrivka
# Processing Record 42 of Set 5 | kahului
# Processing Record 43 of Set 5 | chute-aux-outardes
# Processing Record 44 of Set 5 | hithadhoo
# Processing Record 45 of Set 5 | bonavista
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | north bend
# Processing Record 48 of Set 5 | newport
# Processing Record 49 of Set 5 | mount isa
# Processing Record 50 of Set 5 | tuatapere
# Processing Record 1 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | kaeo
# Processing Record 4 of Set 6 | klyuchi
# Processing Record 5 of Set 6 | san cristobal
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | flin flon
# Processing Record 8 of Set 6 | bilma
# Processing Record 9 of Set 6 | bykov
# Processing Record 10 of Set 6 | labuan
# Processing Record 11 of Set 6 | andenes
# Processing Record 12 of Set 6 | horadiz
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | nizhnevartovsk
# Processing Record 16 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | east london
# Processing Record 18 of Set 6 | pekan
# Processing Record 19 of Set 6 | itoman
# Processing Record 20 of Set 6 | zapolyarnyy
# Processing Record 21 of Set 6 | manali
# Processing Record 22 of Set 6 | plettenberg bay
# Processing Record 23 of Set 6 | skiros
# City not found. Skipping...
# Processing Record 24 of Set 6 | cayenne
# Processing Record 25 of Set 6 | homer
# Processing Record 26 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | dubti
# Processing Record 28 of Set 6 | tigil
# Processing Record 29 of Set 6 | roald
# Processing Record 30 of Set 6 | faanui
# Processing Record 31 of Set 6 | nikolskoye
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | kupang
# Processing Record 34 of Set 6 | la ronge
# Processing Record 35 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 6 | san jose
# Processing Record 37 of Set 6 | half moon bay
# Processing Record 38 of Set 6 | campoverde
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | terrak
# Processing Record 41 of Set 6 | yinchuan
# Processing Record 42 of Set 6 | ures
# Processing Record 43 of Set 6 | atambua
# Processing Record 44 of Set 6 | asbe teferi
# Processing Record 45 of Set 6 | clyde river
# Processing Record 46 of Set 6 | katherine
# Processing Record 47 of Set 6 | trairi
# Processing Record 48 of Set 6 | port blair
# Processing Record 49 of Set 6 | tanout
# Processing Record 50 of Set 6 | odesskoye
# Processing Record 1 of Set 7 | bontang
# Processing Record 2 of Set 7 | kampen
# Processing Record 3 of Set 7 | ko samui
# Processing Record 4 of Set 7 | rocha
# Processing Record 5 of Set 7 | reyes
# Processing Record 6 of Set 7 | povenets
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | henties bay
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | portland
# Processing Record 12 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 7 | pietarsaari
# Processing Record 14 of Set 7 | zhoucheng
# Processing Record 15 of Set 7 | monrovia
# Processing Record 16 of Set 7 | kouango
# Processing Record 17 of Set 7 | kasongo-lunda
# Processing Record 18 of Set 7 | ojinaga
# Processing Record 19 of Set 7 | padang
# Processing Record 20 of Set 7 | lasa
# Processing Record 21 of Set 7 | rameswaram
# Processing Record 22 of Set 7 | bilibino
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | boa vista
# Processing Record 25 of Set 7 | okhotsk
# Processing Record 26 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 7 | frederick
# Processing Record 28 of Set 7 | kutina
# Processing Record 29 of Set 7 | meulaboh
# Processing Record 30 of Set 7 | bentiu
# Processing Record 31 of Set 7 | aswan
# Processing Record 32 of Set 7 | airai
# Processing Record 33 of Set 7 | lompoc
# Processing Record 34 of Set 7 | puerto escondido
# Processing Record 35 of Set 7 | samsun
# Processing Record 36 of Set 7 | surin
# Processing Record 37 of Set 7 | dhidhdhoo
# Processing Record 38 of Set 7 | baiyin
# Processing Record 39 of Set 7 | toora-khem
# Processing Record 40 of Set 7 | mount gambier
# Processing Record 41 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 7 | el paso
# Processing Record 43 of Set 7 | gat
# Processing Record 44 of Set 7 | granard
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | lavrentiya
# Processing Record 47 of Set 7 | hillsborough
# Processing Record 48 of Set 7 | manzhouli
# Processing Record 49 of Set 7 | chaihe
# Processing Record 50 of Set 7 | rawson
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | baykit
# Processing Record 4 of Set 8 | dongsheng
# Processing Record 5 of Set 8 | bacalar
# Processing Record 6 of Set 8 | leca da palmeira
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | kamenka
# Processing Record 9 of Set 8 | vardo
# Processing Record 10 of Set 8 | timra
# Processing Record 11 of Set 8 | fortuna
# Processing Record 12 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 8 | mezen
# Processing Record 14 of Set 8 | ajaccio
# Processing Record 15 of Set 8 | grand gaube
# Processing Record 16 of Set 8 | oksfjord
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | dengzhou
# Processing Record 19 of Set 8 | bahia blanca
# Processing Record 20 of Set 8 | flinders
# Processing Record 21 of Set 8 | clovis
# Processing Record 22 of Set 8 | palmetto
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | chateaudun
# Processing Record 26 of Set 8 | brae
# Processing Record 27 of Set 8 | husavik
# Processing Record 28 of Set 8 | thai binh
# Processing Record 29 of Set 8 | svetlyy
# Processing Record 30 of Set 8 | manyana
# Processing Record 31 of Set 8 | saint-philippe
# Processing Record 32 of Set 8 | manggar
# Processing Record 33 of Set 8 | tonantins
# Processing Record 34 of Set 8 | nuevitas
# Processing Record 35 of Set 8 | santa maria
# Processing Record 36 of Set 8 | shenjiamen
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | smithers
# Processing Record 39 of Set 8 | berdigestyakh
# Processing Record 40 of Set 8 | vao
# Processing Record 41 of Set 8 | harper
# Processing Record 42 of Set 8 | nongstoin
# Processing Record 43 of Set 8 | ambon
# Processing Record 44 of Set 8 | mpika
# Processing Record 45 of Set 8 | laguna
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | yumen
# Processing Record 48 of Set 8 | thibodaux
# Processing Record 49 of Set 8 | camacha
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | tadine
# Processing Record 3 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 9 | bulgan
# Processing Record 5 of Set 9 | warri
# Processing Record 6 of Set 9 | banikoara
# Processing Record 7 of Set 9 | coihaique
# Processing Record 8 of Set 9 | atar
# Processing Record 9 of Set 9 | chiang rai
# Processing Record 10 of Set 9 | san rafael
# Processing Record 11 of Set 9 | vestmanna
# Processing Record 12 of Set 9 | teknaf
# Processing Record 13 of Set 9 | hun
# Processing Record 14 of Set 9 | nyahururu
# Processing Record 15 of Set 9 | sampit
# Processing Record 16 of Set 9 | sarkand
# Processing Record 17 of Set 9 | port moresby
# Processing Record 18 of Set 9 | gotsu
# Processing Record 19 of Set 9 | ippy
# Processing Record 20 of Set 9 | archidona
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | kaya
# Processing Record 23 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 9 | coxim
# Processing Record 25 of Set 9 | oudtshoorn
# Processing Record 26 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 9 | hambantota
# Processing Record 28 of Set 9 | poso
# Processing Record 29 of Set 9 | srednekolymsk
# Processing Record 30 of Set 9 | prince rupert
# Processing Record 31 of Set 9 | zatoka
# Processing Record 32 of Set 9 | mogadishu
# Processing Record 33 of Set 9 | walvis bay
# Processing Record 34 of Set 9 | barkly west
# Processing Record 35 of Set 9 | nador
# Processing Record 36 of Set 9 | bystryy istok
# Processing Record 37 of Set 9 | aras
# Processing Record 38 of Set 9 | talnakh
# Processing Record 39 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 9 | chicama
# Processing Record 41 of Set 9 | hamilton
# Processing Record 42 of Set 9 | darhan
# Processing Record 43 of Set 9 | herat
# Processing Record 44 of Set 9 | alamosa
# Processing Record 45 of Set 9 | lithakia
# Processing Record 46 of Set 9 | tabuny
# Processing Record 47 of Set 9 | meridian
# Processing Record 48 of Set 9 | havoysund
# Processing Record 49 of Set 9 | shilovo
# Processing Record 50 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 10 | nelson bay
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 4 of Set 10 | antofagasta
# Processing Record 5 of Set 10 | saint-leu
# Processing Record 6 of Set 10 | sao filipe
# Processing Record 7 of Set 10 | teguise
# Processing Record 8 of Set 10 | mindelo
# Processing Record 9 of Set 10 | gunnedah
# Processing Record 10 of Set 10 | thio
# Processing Record 11 of Set 10 | xiongyue
# Processing Record 12 of Set 10 | svetlogorsk
# Processing Record 13 of Set 10 | kashi
# Processing Record 14 of Set 10 | quatre cocos
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | panzhihua
# Processing Record 17 of Set 10 | boden
# Processing Record 18 of Set 10 | saint pete beach
# Processing Record 19 of Set 10 | mabaruma
# Processing Record 20 of Set 10 | malangwa
# Processing Record 21 of Set 10 | ouidah
# Processing Record 22 of Set 10 | pringsewu
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | fort morgan
# Processing Record 25 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 10 | yeppoon
# Processing Record 27 of Set 10 | amurzet
# Processing Record 28 of Set 10 | epe
# Processing Record 29 of Set 10 | minden
# Processing Record 30 of Set 10 | itarema
# Processing Record 31 of Set 10 | ahipara
# Processing Record 32 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 10 | tongliao
# Processing Record 34 of Set 10 | pervoye maya
# Processing Record 35 of Set 10 | tougue
# Processing Record 36 of Set 10 | kindu
# Processing Record 37 of Set 10 | bowen
# Processing Record 38 of Set 10 | wattegama
# Processing Record 39 of Set 10 | camana
# Processing Record 40 of Set 10 | yaring
# Processing Record 41 of Set 10 | pontalina
# Processing Record 42 of Set 10 | kropotkin
# Processing Record 43 of Set 10 | naryan-mar
# Processing Record 44 of Set 10 | huaibei
# Processing Record 45 of Set 10 | bardiyah
# Processing Record 46 of Set 10 | jiangmen
# Processing Record 47 of Set 10 | karuzi
# Processing Record 48 of Set 10 | keetmanshoop
# Processing Record 49 of Set 10 | qandala
# Processing Record 50 of Set 10 | honiara
# Processing Record 1 of Set 11 | betanzos
# Processing Record 2 of Set 11 | muros
# Processing Record 3 of Set 11 | amalapuram
# Processing Record 4 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 11 | barentu
# Processing Record 6 of Set 11 | rio verde de mato grosso
# Processing Record 7 of Set 11 | sinnamary
# Processing Record 8 of Set 11 | estevan
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | bouna
# Processing Record 11 of Set 11 | areka
# Processing Record 12 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 11 | rognan
# Processing Record 14 of Set 11 | tarauaca
# Processing Record 15 of Set 11 | ilhabela
# Processing Record 16 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 11 | ucluelet
# Processing Record 18 of Set 11 | matagami
# Processing Record 19 of Set 11 | yar-sale
# Processing Record 20 of Set 11 | sorland
# Processing Record 21 of Set 11 | oranjestad
# Processing Record 22 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 11 | la palma
# Processing Record 25 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 11 | pimentel
# Processing Record 27 of Set 11 | sterling
# Processing Record 28 of Set 11 | obo
# Processing Record 29 of Set 11 | sibolga
# Processing Record 30 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 11 | astara
# Processing Record 32 of Set 11 | severodvinsk
# Processing Record 33 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | nome
# Processing Record 36 of Set 11 | tura
# Processing Record 37 of Set 11 | port hardy
# Processing Record 38 of Set 11 | beroroha
# Processing Record 39 of Set 11 | mayo
# Processing Record 40 of Set 11 | nandura
# Processing Record 41 of Set 11 | nahan
# Processing Record 42 of Set 11 | rio grande
# Processing Record 43 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 11 | richards bay
# Processing Record 45 of Set 11 | ca mau
# Processing Record 46 of Set 11 | hennenman
# Processing Record 47 of Set 11 | sola
# Processing Record 48 of Set 11 | necochea
# Processing Record 49 of Set 11 | urambo
# Processing Record 50 of Set 11 | dunmanway
# Processing Record 1 of Set 12 | tadpatri
# Processing Record 2 of Set 12 | pincher creek
# Processing Record 3 of Set 12 | gallup
# Processing Record 4 of Set 12 | gualaquiza
# Processing Record 5 of Set 12 | wasilla
# Processing Record 6 of Set 12 | atbasar
# Processing Record 7 of Set 12 | dunedin
# Processing Record 8 of Set 12 | pytalovo
# Processing Record 9 of Set 12 | geraldton
# Processing Record 10 of Set 12 | dryden
# Processing Record 11 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 12 | jardim
# Processing Record 13 of Set 12 | cabo rojo
# Processing Record 14 of Set 12 | lubango
# Processing Record 15 of Set 12 | broome
# Processing Record 16 of Set 12 | shahr-e babak
# Processing Record 17 of Set 12 | pacific grove
# Processing Record 18 of Set 12 | ichnya
# Processing Record 19 of Set 12 | cochrane
# Processing Record 20 of Set 12 | skibbereen
# Processing Record 21 of Set 12 | sungaipenuh
# Processing Record 22 of Set 12 | gizo
# Processing Record 23 of Set 12 | zhangye
# Processing Record 24 of Set 12 | sartana
# Processing Record 25 of Set 12 | sandpoint
# Processing Record 26 of Set 12 | praia da vitoria
# Processing Record 27 of Set 12 | neryungri
# Processing Record 28 of Set 12 | gurupa
# Processing Record 29 of Set 12 | presidente medici
# Processing Record 30 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 12 | iranshahr
# Processing Record 32 of Set 12 | shupiyan
# Processing Record 33 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 12 | abu dhabi
# Processing Record 35 of Set 12 | tomatlan
# Processing Record 36 of Set 12 | guangyuan
# Processing Record 37 of Set 12 | sinjar
# Processing Record 38 of Set 12 | cap malheureux
# Processing Record 39 of Set 12 | stillwater
# Processing Record 40 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 41 of Set 12 | jacksonville
# Processing Record 42 of Set 12 | shimonoseki
# Processing Record 43 of Set 12 | mankapur
# Processing Record 44 of Set 12 | nanakuli
# Processing Record 45 of Set 12 | huntsville
# Processing Record 46 of Set 12 | alice springs
# Processing Record 47 of Set 12 | stulovo
# Processing Record 48 of Set 12 | gilgit
# Processing Record 49 of Set 12 | severnoye
# Processing Record 50 of Set 12 | kokopo
# Processing Record 1 of Set 13 | ovsyanka
# Processing Record 2 of Set 13 | negara
# Processing Record 3 of Set 13 | hohhot
# Processing Record 4 of Set 13 | vagur
# Processing Record 5 of Set 13 | caravelas
# Processing Record 6 of Set 13 | taquarituba
# Processing Record 7 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 13 | adrar
# Processing Record 9 of Set 13 | san francisco
# Processing Record 10 of Set 13 | kudat
# Processing Record 11 of Set 13 | barrhead
# Processing Record 12 of Set 13 | mangrol
# Processing Record 13 of Set 13 | san juan
# Processing Record 14 of Set 13 | eyl
# Processing Record 15 of Set 13 | balkhash
# Processing Record 16 of Set 13 | goure
# Processing Record 17 of Set 13 | sitka
# Processing Record 18 of Set 13 | sangar
# Processing Record 19 of Set 13 | kushiro
# Processing Record 20 of Set 13 | adilcevaz
# Processing Record 21 of Set 13 | abu zabad
# Processing Record 22 of Set 13 | ouegoa
# Processing Record 23 of Set 13 | quzhou
# Processing Record 24 of Set 13 | chapais
# Processing Record 25 of Set 13 | champerico
# Processing Record 26 of Set 13 | sahbuz
# Processing Record 27 of Set 13 | alugan
# Processing Record 28 of Set 13 | gravdal
# Processing Record 29 of Set 13 | terrace
# Processing Record 30 of Set 13 | north myrtle beach
# Processing Record 31 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 32 of Set 13 | pocone
# Processing Record 33 of Set 13 | boyolangu
# Processing Record 34 of Set 13 | skelleftea
# Processing Record 35 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 13 | maldonado
# Processing Record 37 of Set 13 | sobolevo
# Processing Record 38 of Set 13 | sanming
# Processing Record 39 of Set 13 | peniche
# Processing Record 40 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 13 | piombino
# Processing Record 42 of Set 13 | atherton
# Processing Record 43 of Set 13 | comodoro rivadavia
# Processing Record 44 of Set 13 | saryg-sep
# Processing Record 45 of Set 13 | palmas
# Processing Record 46 of Set 13 | braniewo
# Processing Record 47 of Set 13 | zaria
# Processing Record 48 of Set 13 | erdenet
# Processing Record 49 of Set 13 | garwa
# Processing Record 50 of Set 13 | ola
# Processing Record 1 of Set 14 | borisoglebskiy
# Processing Record 2 of Set 14 | pitimbu
# Processing Record 3 of Set 14 | ishigaki
# Processing Record 4 of Set 14 | amqui
# Processing Record 5 of Set 14 | bikaner
# Processing Record 6 of Set 14 | varzea da palma
# Processing Record 7 of Set 14 | manadhoo
# Processing Record 8 of Set 14 | kimbe
# Processing Record 9 of Set 14 | lichinga
# Processing Record 10 of Set 14 | aksha
# Processing Record 11 of Set 14 | cardston
# Processing Record 12 of Set 14 | assentoft
# Processing Record 13 of Set 14 | shyroke
# Processing Record 14 of Set 14 | tautira
# Processing Record 15 of Set 14 | buala
# Processing Record 16 of Set 14 | mana
# Processing Record 17 of Set 14 | sedalia
# Processing Record 18 of Set 14 | kirovskiy
# Processing Record 19 of Set 14 | nagato
# Processing Record 20 of Set 14 | touros
# Processing Record 21 of Set 14 | charters towers
# Processing Record 22 of Set 14 | bitung
# Processing Record 23 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 14 | spearfish
# Processing Record 25 of Set 14 | oktyabrskoye
# Processing Record 26 of Set 14 | stony plain
# Processing Record 27 of Set 14 | talaya
# Processing Record 28 of Set 14 | faya
# Processing Record 29 of Set 14 | kopervik
# Processing Record 30 of Set 14 | tsumeb
# Processing Record 31 of Set 14 | taoudenni
# Processing Record 32 of Set 14 | pop
# Processing Record 33 of Set 14 | iskateley
# Processing Record 34 of Set 14 | kindersley
# Processing Record 35 of Set 14 | naze
# Processing Record 36 of Set 14 | tibacuy
# Processing Record 37 of Set 14 | iguatemi
# Processing Record 38 of Set 14 | kitui
# Processing Record 39 of Set 14 | kuching
# Processing Record 40 of Set 14 | praya
# Processing Record 41 of Set 14 | olenino
# Processing Record 42 of Set 14 | grudziadz
# Processing Record 43 of Set 14 | egvekinot
# Processing Record 44 of Set 14 | leh
# Processing Record 45 of Set 14 | skjervoy
# Processing Record 46 of Set 14 | nurota
# Processing Record 47 of Set 14 | matanza
# Processing Record 48 of Set 14 | antalaha
# Processing Record 49 of Set 14 | bell ville
# Processing Record 50 of Set 14 | lima
# Processing Record 1 of Set 15 | marsa matruh
# Processing Record 2 of Set 15 | sao paulo de olivenca
# Processing Record 3 of Set 15 | wheatley
# Processing Record 4 of Set 15 | minab
# Processing Record 5 of Set 15 | mizdah
# Processing Record 6 of Set 15 | mumbwa
# Processing Record 7 of Set 15 | goderich
# Processing Record 8 of Set 15 | rexburg
# Processing Record 9 of Set 15 | banda aceh
# Processing Record 10 of Set 15 | nha trang
# Processing Record 11 of Set 15 | xapuri
# Processing Record 12 of Set 15 | santa barbara
# Processing Record 13 of Set 15 | biltine
# Processing Record 14 of Set 15 | mayumba
# Processing Record 15 of Set 15 | teahupoo
# Processing Record 16 of Set 15 | ahuimanu
# Processing Record 17 of Set 15 | manaquiri
# Processing Record 18 of Set 15 | paris
# Processing Record 19 of Set 15 | olinda
# Processing Record 20 of Set 15 | manaus
# Processing Record 21 of Set 15 | bambanglipuro
# Processing Record 22 of Set 15 | high level
# Processing Record 23 of Set 15 | tawang
# Processing Record 24 of Set 15 | sistranda
# Processing Record 25 of Set 15 | honningsvag
# Processing Record 26 of Set 15 | northam
# Processing Record 27 of Set 15 | sawakin
# Processing Record 28 of Set 15 | kudahuvadhoo
# Processing Record 29 of Set 15 | kununurra
# Processing Record 30 of Set 15 | piranhas
# Processing Record 31 of Set 15 | saint-augustin
# Processing Record 32 of Set 15 | rosario do sul
# Processing Record 33 of Set 15 | avera
# Processing Record 34 of Set 15 | izumo
# Processing Record 35 of Set 15 | lakes entrance
# Processing Record 36 of Set 15 | mahon
# Processing Record 37 of Set 15 | saldanha
# Processing Record 38 of Set 15 | winnemucca
# Processing Record 39 of Set 15 | severo-kurilsk
# Processing Record 40 of Set 15 | estelle
# Processing Record 41 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 15 | nantucket
# Processing Record 43 of Set 15 | saint-pierre
# Processing Record 44 of Set 15 | brandon
# Processing Record 45 of Set 15 | mecca
# Processing Record 46 of Set 15 | okoneshnikovo
# Processing Record 47 of Set 15 | tete
# Processing Record 48 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 15 | samarai
# Processing Record 1 of Set 16 | juneau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini      TO -21.2000 -175.2000     68.00        94          20
# 1          Avarua      CK -21.2078 -159.7750     77.00       100          20
# 2         Albanel      CA  48.8832  -72.4487     55.40        50          97
# 3        Buraydah      SA  26.3260   43.9750     84.20        26           0
# 4         Mataura      NZ -46.1927  168.8643     55.99        92          97
# 5    Saint George      US  37.1041 -113.5841     66.99        17           1
# 6            Hofn      IS  64.2539  -15.2082     33.44        40           0
# 7  Ribeira Grande      PT  38.5167  -28.7000     64.40        88          75
# 8         Ushuaia      AR -54.8000  -68.3000     53.60        54          40
# 9          Torbay      CA  47.6666  -52.7314     32.00        93          90
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1        3.44          few clouds
# 2        6.91     overcast clouds
# 3       17.27           clear sky
# 4        1.99     overcast clouds
# 5        1.83           clear sky
# 6        5.39           clear sky
# 7       10.36       broken clouds
# 8        8.05    scattered clouds
# 9       19.57                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.count()
# Out:
# City                   692
# Country                692
# Lat                    692
# Lng                    692
# Max Temp               692
# Humidity               692
# Cloudiness             692
# Wind Speed             692
# Current Description    692
# dtype: int64
